# %% [markdown]
# ## NLP Tast 중 하나인 Semantic texual similarity(STS) 활용
# - 유저(A)가 작성한 소개글로 **문장 유사도**를 파악하여 타 유저들이 작성한 소개글 중 가장 유사한 글을 작성한 타 유저(B)를 찾아내보자
# - 카카오브레인의 Pororo 사용

# %% [markdown]
# ### `1. 필요 라이브러리 import`

# %%
import pandas as pd
import numpy as np
import torch

import urllib.request

from pororo import Pororo
from sentence_transformers import SentenceTransformer

# %%
from tqdm import tqdm
tqdm.pandas()

# %%
data = pd.read_csv('user_Introduction.csv')
data
# Out:
#       user_id Sex  Age location  \
# 0           0  여성  40대        b
# 1           1  남성  40대        k
# 2           2  남성  30대        b
# 3           3  남성  40대        e
# 4           4  여성  20대        h
# ...       ...  ..  ...      ...
# 3191     3191  남성  40대        h
# 3192     3192  남성  50대        h
# 3193     3193  남성  40대        o
# 3194     3194  남성  40대        h
# 3195     3195  남성  40대        b
#
#                                            Introduction
# 0     좋은 인연을 만나기가 참 힘드네요  서로 배려해주고 아껴주는  친구처럼 편안한 사람...
# 1     중소기업이지만 동일업계에서 인정받는 회사에 임원입니다.  안정적인 직장에 안정적인 ...
# 2     안녕하세요.  저는 부천 있는 중소기업 현장에서 근무하고 있습니다. 나이가 있는 관...
# 3            저는 개발자입니다. 저랑 남아있는 생을 행복하게 함께보낼 배우자를 찾습니다.
# 4                                    🌼🌻🌼   여자 입니다 🌻🌼🌻dd
# ...                                                 ...
# 3191  저는 이것저것? 장사를 하고 이 어려운 시기 잘? 버티고 있습니다ㅜㅜ 그쪽도 그런가...
# 3192  다정다감하며 늘 긍정적이며 후회없는 삶을 위해 노력하며 생활합니다. 서로에게 위로가...
# 3193  안녕하세요~ 천안에 살고 있는 이해심, 배려심 많은 순수남입니다. 앞만 보고 달려오...
# 3194  안녕하세요 평범한 남자 입니다 좋은 인연 되었으면 줗겠습니다 비흡연 이구요 친구같은...
# 3195  이제 혼자가 이닌 남은 인생에동반자 같이할 나의님을 찿을수있을까?해서이곳에서 기다립...
#
# [3196 rows x 5 columns]

# %% [markdown]
# - `user_id` : 회원 번호
# - `Sex` : 성별
# - `Age` : 나이대
# - `location` : 지역
# - `Introudction` : 소개글

# %%
# %%time
model = Pororo(task="sentence_embedding", lang="ko")
# Out:
# CPU times: user 3.39 s, sys: 1.04 s, total: 4.43 s
# Wall time: 4.08 s

# %% [markdown]
# ### `2. 기본 전처리`

# %%
import re

# %%
def basic_preprocessing(df,col):
    df.drop(df[df[col].isnull()].index, inplace=True)
    df.reset_index(drop=True, inplace=True)
    print('Isnull?', df[col].isnull().sum())
    
    # 공백 제거
    df[col] = df[col].apply(lambda x: x.strip())
    
    # 특수문자, 단모음/단자음 제거
    df[col] = df[col].apply(lambda x: re.sub(r'[\n\r]', '',x))
    df[col] = df[col].apply(lambda x: re.sub('[ㄱ-ㅎㅏ-ㅣ]+','',x))
    df[col] = df[col].apply(lambda x: re.sub('[a-zA-Z]','',x))
    df[col] = df[col].apply(lambda x: re.sub('[-=+,#/\?:^.@*\"※~ㆍ!』‘|\(\)\[\]`\'…》\”\“\’·]','',x))    
    
    # utf-8 encode
    df[col] = df[col].apply(lambda x: x.encode('utf-8','ignore').decode('utf-8'))
    
    # 이모티콘 (이모지) 제거
    def del_emoji (text):
        only_BMP_pattern = re.compile("["
        u"\U00010000-\U0010FFFF"  #BMP characters 이외
                           "]+", flags=re.UNICODE)
        return only_BMP_pattern.sub(r'', text)
    
    df[col] = df[col].apply(del_emoji)

    return df

# %%
data = basic_preprocessing(data, 'Introduction')
# Out:
# Isnull? 0

# %%
display(data[data['Introduction']==''])
data.drop(data[data['Introduction']==''].index, inplace=True)
# Out:
#       user_id Sex   Age location Introduction
# 130       130  여성   20대        h
# 185       186  남성   20대        h
# 250       251  남성  100대        f
# 1584     1586  남성   40대        k
# 2371     2373  여성   40대        k

# %% [markdown]
# ### `3. 유사도 추출`
#
#      성별에 따라 유사한 회원 3명을 보여줌 (남성회원에게는 여성회원, 여성회원에게는 남성회원)
#      *위의 경우에는 같은 나이대 회원을 보여줌*

# %% [markdown]
# ### **`Case 2`**

# %%
df = data.copy()

# %%
df.loc[0,'Sex']
# Out:
# '여성'

# %% [markdown]
# `(1) 성별, 나이 split`

# %%
class generator:
    
    def __init__(self,df):
        self.df = df

    def split_sex(self,user_df):
        if user_df.loc[0,'Sex']=='여성':
            target_df= self.df[self.df['Sex']=='남성'].reset_index(drop=True)
        elif user_df.loc[0,'Sex'] =='남성':
            target_df = self.df[self.df['Sex']=='여성'].reset_index(drop=True)
        else:
            raise Exception('Invalid mem_sex value')

        return target_df
    
    def split_age(self,user_df, target_df):
        
        user_age = user_df.loc[0,'Age']
        
        if user_df.loc[0,'Sex'] =='여성':
            target_df = target_df[target_df['Age']==user_age]  
        elif user_df.loc[0,'Sex'] =='남성':
            target_df = target_df[target_df['Age']==user_age]
        else:
            raise Exception('Invalid Age value')
    
        return target_df

# %% [markdown]
# `(2) similar embedding`

# %%
from sentence_transformers import util

class get_similar_user(generator):
     
    def __init__(self, df):
        self.df = df
               
    def return_df(self,user_df):
        
        def cos_sim(A, B):
            return round(dot(A, B)/(norm(A)*norm(B)), 3)
        
        def calc_similarity(query_embedding, corpus_embeddings):
            cos_scores = util.pytorch_cos_sim(query_embedding, corpus_embeddings)[0]
            cos_scores = cos_scores.cpu()
            cos_scores = cos_scores.detach().numpy().tolist()[0]
            cos_scores = round(cos_scores, 3)
            return cos_scores    
        

        target_df = self.split_sex(user_df)
        target_df = self.split_age(user_df=user_df,target_df=target_df)
        
        # Introduction embedding 
        target_df['mate_embedding'] = target_df['Introduction'].progress_map(model)
        user_emb = model(user_df['Introduction'][0])  
        target_df['similar_score'] = target_df['mate_embedding'].progress_map(lambda x: calc_similarity(user_emb, x))
        
        # 상위 3명 Top-3뽑기
        target_df.sort_values(by ='similar_score', ascending=False, inplace=True)
        target_df.drop(columns='mate_embedding', inplace=True)
        result = target_df[:3].reset_index(drop=True)
        
        
        return result

# %% [markdown]
# `(3) 조건 거르기`

# %%
class check_condition(get_similar_user):
    
    def __init__(self, df, user_df):
        self.df = df
        self.user_df = user_df
        self.target_df = self.return_df(user_df)
        
    def loc_condition(self):
        user_loc = self.user_df['location'][0]
        loc_sim_df = self.target_df[self.target_df['location']==user_loc].reset_index(drop=True)
        
        return loc_sim_df

# %% [markdown]
# ### ``main``

# %%
class final_get_user(check_condition):
    
    def __init__(self,df):
        self.df = df
    
    def get_final_user(self):
        
        get_final_df = pd.DataFrame()
        
        for i in range(self.df.shape[0]):
            user_df = self.df.iloc[i].to_frame().transpose().reset_index(drop=True)
            target_df = self.return_df(user_df)
            score = target_df['similar_score']
            target_df.drop(columns='similar_score', inplace=True)
            target_df.columns = ['ptr_'+col for col in user_df.columns]
            
            result = pd.concat([user_df,target_df])
            result['score'] = score
            result.fillna(method='ffill')
            
            get_final_df = pd.concat([get_final_df, result])
            
        return get_final_df

# %%
fgu = final_get_user(df)

# %%
result_df = fgu.get_final_user()
result_df
# Out:
# 100%|██████████| 942/942 [00:19<00:00, 48.96it/s]
# 100%|██████████| 942/942 [00:00<00:00, 13868.78it/s]
# 100%|██████████| 237/237 [00:05<00:00, 47.10it/s]
# 100%|██████████| 237/237 [00:00<00:00, 
/s]
# 100%|██████████| 211/211 [00:00<00:00, 13658.22it/s]
# 100%|██████████| 76/76 [00:01<00:00, 50.48it/s]
# 100%|██████████| 76/76 [00:00<00:00, 12894.07it/s]
# 100%|██████████| 211/211 [00:03<00:00, 52.88it/s]
# 100%|██████████| 211/211 [00:00<00:00, 13865.79it/s]
# 100%|██████████| 211/211 [00:04<00:00, 52.05it/s]
# 100%|██████████| 211/211 [00:00<00:00, 14670.26it/s]
# 100%|██████████| 211/211 [00:03<00:00, 56.48it/s]
# 100%|██████████| 211/211 [00:00<00:00, 14620.58it/s]
# 100%|██████████| 237/237 [00:05<00:00, 47.05it/s]
# 100%|██████████| 237/237 [00:00<00:00, 14320.81it/s]
# 100%|██████████| 581/581 [00:10<00:00, 53.85it/s]
# 100%|██████████| 581/581 [00:00<00:00, 14799.62it/s]
# 100%|██████████| 942/942 [00:19<00:00, 48.95it/s]
# 100%|██████████| 942/942 [00:00<00:00, 13715.15it/s]
# 100%|██████████| 237/237 [00:04<00:00, 47.96it/s]
# 100%|██████████| 237/237 [00:00<00:00, 14355.55it/s]
#  23%|██▎       | 48/211 [00:00<00:02, 59.59it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-16-039995247ed6> in <module>
# ----> 1 result_df = fgu.get_final_user()
#       2 result_df
#
# <ipython-input-14-86f99233ef32> in get_final_user(self)
#      10         for i in range(self.df.shape[0]):
#      11             user_df = self.df.iloc[i].to_frame().transpose().reset_index(drop=True)
# ---> 12             target_df = self.return_df(user_df)
#      13             score = target_df['similar_score']
#      14             target_df.drop(columns='similar_score', inplace=True)
#
# <ipython-input-12-8cb335878f3a> in return_df(self, user_df)
#      23
#      24         # Introduction embedding
# ---> 25         target_df['mate_embedding'] = target_df['Introduction'].progress_map(model)
#      26         user_emb = model(user_df['Introduction'][0])
#      27         target_df['similar_score'] = target_df['mate_embedding'].progress_map(lambda x: calc_similarity(user_emb, x))
#
# ~/anaconda3/envs/nlp/lib/python3.7/site-packages/tqdm/std.py in inner(df, func, *args, **kwargs)
#     812                 # on the df using our wrapper (which provides bar updating)
#     813                 try:
# --> 814                     return getattr(df, df_function)(wrapper, **kwargs)
#     815                 finally:
#     816                     t.close()
#
# ~/anaconda3/envs/nlp/lib/python3.7/site-packages/pandas/core/series.py in map(self, arg, na_action)
#    3968         dtype: object
#    3969         """
# -> 3970         new_values = super()._map_values(arg, na_action=na_action)
#    3971         return self._constructor(new_values, index=self.index).__finalize__(
#    3972             self, method="map"
#
# ~/anaconda3/envs/nlp/lib/python3.7/site-packages/pandas/core/base.py in _map_values(self, mapper, na_action)
#    1158
#    1159         # mapper is a function
# -> 1160         new_values = map_f(values, mapper)
#    1161
#    1162         return new_values
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# ~/anaconda3/envs/nlp/lib/python3.7/site-packages/tqdm/std.py in wrapper(*args, **kwargs)
#     807                     # take a fast or slow code path; so stop when t.total==t.n
#     808                     t.update(n=1 if not t.total or t.n < t.total else 0)
# --> 809                     return func(*args, **kwargs)
#     810
#     811                 # Apply the provided function (in **kwargs)
#
# ~/anaconda3/envs/nlp/lib/python3.7/site-packages/pororo/tasks/utils/base.py in __call__(self, text, **kwargs)
#     111
#     112     def __call__(self, text: str, **kwargs):
# --> 113         return self.predict(text, **kwargs)
#     114
#     115
#
# ~/anaconda3/envs/nlp/lib/python3.7/site-packages/pororo/tasks/sentence_embedding.py in predict(self, sent, **kwargs)
#     185
#     186         """
# --> 187         outputs = self._model.encode([sent])[0]
#     188         return outputs
#
# ~/anaconda3/envs/nlp/lib/python3.7/site-packages/sentence_transformers/SentenceTransformer.py in encode(self, sentences, batch_size, show_progress_bar, output_value, convert_to_numpy, convert_to_tensor, device, normalize_embeddings)
#     162
#     163             with torch.no_grad():
# --> 164                 out_features = self.forward(features)
#     165
#     166                 if output_value == 'token_embeddings':
#
# ~/anaconda3/envs/nlp/lib/python3.7/site-packages/torch/nn/modules/container.py in forward(self, input)
#     139     def forward(self, input):
#     140         for module in self:
# --> 141             input = module(input)
#     142         return input
#     143
#
# ~/anaconda3/envs/nlp/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/anaconda3/envs/nlp/lib/python3.7/site-packages/pororo/models/brainsbert/BrainRoBERTa.py in forward(self, features)
#      46
#      47     def forward(self, features):
# ---> 48         output_states = self.roberta(**features)
#      49         output_tokens = output_states[0]
#      50
#
# ~/anaconda3/envs/nlp/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/anaconda3/envs/nlp/lib/python3.7/site-packages/transformers/models/roberta/modeling_roberta.py in forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     851             output_attentions=output_attentions,
#     852             output_hidden_states=output_hidden_states,
# --> 853             return_dict=return_dict,
#     854         )
#     855         sequence_output = encoder_outputs[0]
#
# ~/anaconda3/envs/nlp/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/anaconda3/envs/nlp/lib/python3.7/site-packages/transformers/models/roberta/modeling_roberta.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     527                     encoder_attention_mask,
#     528                     past_key_value,
# --> 529                     output_attentions,
#     530                 )
#     531
#
# ~/anaconda3/envs/nlp/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/anaconda3/envs/nlp/lib/python3.7/site-packages/transformers/models/roberta/modeling_roberta.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     448
#     449         layer_output = apply_chunking_to_forward(
# --> 450             self.feed_forward_chunk, self.chunk_size_feed_forward, self.seq_len_dim, attention_output
#     451         )
#     452         outputs = (layer_output,) + outputs
#
# ~/anaconda3/envs/nlp/lib/python3.7/site-packages/transformers/modeling_utils.py in apply_chunking_to_forward(forward_fn, chunk_size, chunk_dim, *input_tensors)
#    2194         return torch.cat(output_chunks, dim=chunk_dim)
#    2195
# -> 2196     return forward_fn(*input_tensors)
#
# ~/anaconda3/envs/nlp/lib/python3.7/site-packages/transformers/models/roberta/modeling_roberta.py in feed_forward_chunk(self, attention_output)
#     460     def feed_forward_chunk(self, attention_output):
#     461         intermediate_output = self.intermediate(attention_output)
# --> 462         layer_output = self.output(intermediate_output, attention_output)
#     463         return layer_output
#     464
#
# ~/anaconda3/envs/nlp/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/anaconda3/envs/nlp/lib/python3.7/site-packages/transformers/models/roberta/modeling_roberta.py in forward(self, hidden_states, input_tensor)
#     374
#     375     def forward(self, hidden_states, input_tensor):
# --> 376         hidden_states = self.dense(hidden_states)
#     377         hidden_states = self.dropout(hidden_states)
#     378         hidden_states = self.LayerNorm(hidden_states + input_tensor)
#
# ~/anaconda3/envs/nlp/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/anaconda3/envs/nlp/lib/python3.7/site-packages/torch/nn/modules/linear.py in forward(self, input)
#     101
#     102     def forward(self, input: Tensor) -> Tensor:
# --> 103         return F.linear(input, self.weight, self.bias)
#     104
#     105     def extra_repr(self) -> str:
#
# ~/anaconda3/envs/nlp/lib/python3.7/site-packages/torch/nn/functional.py in linear(input, weight, bias)
#    1846     if has_torch_function_variadic(input, weight, bias):
#    1847         return handle_torch_function(linear, (input, weight, bias), input, weight, bias=bias)
# -> 1848     return torch._C._nn.linear(input, weight, bias)
#    1849
#    1850
#
# RuntimeError: CUDA error: CUBLAS_STATUS_INTERNAL_ERROR when calling `cublasSgemm( handle, opa, opb, m, n, k, &alpha, a, lda, b, ldb, &beta, c, ldc)`

# %%
result_df
